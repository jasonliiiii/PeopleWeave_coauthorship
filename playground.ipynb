# %%
import pandas as pd
import json

# %%
with open('data.json') as f:
    data = json.load(f)

# %%
df = pd.DataFrame(data)

# %%
display(df)
# Out:
#                                                            99659859971  \
# preferred name                                                    none
# first name                                                       Junyi
# last name                                                          Shu
# aliases                                                           none
# affiliations                                       [Peking University]
# article count                                                        2
# publication topics   [{'id': 'none', 'name': 'External storage', 'n...
# coAuthors            [{'id': '99659853258', 'preferred name': 'none...
# author publications                                               none
#
#                                                            99659853258  \
# preferred name                                                    none
# first name                                                         Xin
# ...
